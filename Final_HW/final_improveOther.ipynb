# %%
# load package and data
library(ggplot2)
# library(ggalt)

# %%
mos <- read.csv("test.csv")
mos
# Out:
#    Package    Model size k   eta epoch batch_count optimizer Optimizer_lr lr
# 1  ampligraph HolE  6000 300 50  1000  32           adam     1e-03        1e-03
# 2  ampligraph HolE  6000 300 50  3000  32           adam     1e-03        1e-03
# 3  ampligraph HolE  6000 300 50  4000  32           adam     1e-03        1e-03
# 4  ampligraph HolE  6000 300 50  2000  32           adam     1e-03        1e-03
# 5  ampligraph HolE  6000 300 50  4000  32           adam     6e-04        6e-04
# 6  ampligraph HolE  6000 300 50  1000  32           adam     6e-04        6e-04
# 7  ampligraph HolE  6000 300 50  2000  32           adam     6e-04        6e-04
# 8  ampligraph HolE  6000 300 50  3000  32           adam     6e-04        6e-04
# 9  ampligraph HolE  6000 300 50  3000  16           adam     6e-04        6e-04
# 10 ampligraph HolE  6000 300 50  2000  16          sgd       6e-04        6e-04
# 11 ampligraph HolE  6000 300 50  4000  16          sgd       6e-04        6e-04
# ...

# %%
# new version
theme_set(theme_classic())
g <- ggplot(mos, aes(optimizer, Hit.10))
g + geom_boxplot(varwidth=T, fill="plum") + 
    labs(title="Correlation of Hit@10 and Optimizer", 
         subtitle="",
         caption="Source: https://github.com/viviansophie/111-1-econDV",
         x="Optimizer",
         y="Hit@10")
# Out:
# plot without title

# %%
# original
p <- ggplot(mos, aes(x=Hit.10, y=mrr))
p + geom_point()+ 
    geom_smooth(method="loess")+
    labs(title="Correlation of Hit@10 and MRR" )
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
